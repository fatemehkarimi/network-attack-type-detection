# %%
import pandas as pd
import matplotlib.pyplot as plt
from metadata.const import features

# %%
df = pd.read_csv('../dataset/sample.csv')
df.dropna(axis=0, inplace=True)
print(len(df.index))
# Out:
# /tmp/ipykernel_12880/580598843.py:1: DtypeWarning: Columns (85) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../dataset/sample.csv')
# 1048571

# %%
plt.scatter(df[features['label']], df[features['flow_duration']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['total_fwd_packets']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['total_bwd_packets']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['total_len_fwd_packets']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['total_len_bwd_packets']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['fwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['fwd_packet_len_min']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['fwd_packet_len_mean']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['fwd_packet_len_std']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['bwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['bwd_packet_len_min']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['bwd_packet_len_mean']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['bwd_packet_len_std']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['flow_bytes_s']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['flow_packets_s']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['flow_iat_mean']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['flow_iat_std']])
plt.show()

# %%
plt.scatter(df[features['label']], df[features['flow_iat_max']])
plt.show()
