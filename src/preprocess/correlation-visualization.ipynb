# %%
import pandas as pd
import matplotlib.pyplot as plt
from metadata.const import features

# %%
df = pd.read_csv('../dataset/sample-100000.csv')
# Out:
# /tmp/ipykernel_16586/1491459250.py:1: DtypeWarning: Columns (86) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../dataset/sample-100000.csv')

# %%
plt.scatter(df[features['total_bwd_packets']], df[features['total_fwd_packets']])
plt.show()

# %%
plt.scatter(df[features['total_len_bwd_packets']], df[features['total_fwd_packets']])
plt.show()

# %%
plt.scatter(df[features['fwd_packet_len_min']], df[features['fwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['fwd_packet_len_mean']], df[features['fwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['bwd_packet_len_mean']], df[features['bwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['bwd_packet_len_std']], df[features['bwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['flow_bytes_s']], df[features['fwd_packet_len_min']])
plt.show()

# %%
plt.scatter(df[features['flow_iat_std']], df[features['flow_iat_mean']])
plt.show()

# %%
plt.scatter(df[features['flow_iat_max']], df[features['flow_duration']])
plt.show()

# %%
plt.scatter(df[features['fwd_iat_total']], df[features['flow_duration']])
plt.show()

# %%
plt.scatter(df[features['fwd_iat_mean']], df[features['flow_iat_mean']])
plt.show()

# %%
plt.scatter(df[features['fwd_iat_std']], df[features['flow_duration']])
plt.show()

# %%
plt.scatter(df[features['fwd_iat_max']], df[features['flow_duration']])
plt.show()

# %%
plt.scatter(df[features['bwd_iat_total']], df[features['flow_duration']])
plt.show()

# %%
plt.scatter(df[features['bwd_iat_std']], df[features['bwd_iat_mean']])
plt.show()

# %%
plt.scatter(df[features['bwd_iat_max']], df[features['flow_iat_max']])
plt.show()

# %%
plt.scatter(df[features['fwd_packets_s']], df[features['flow_packets_s']])
plt.show()

# %%
plt.scatter(df[features['min_packet_len']], df[features['fwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['max_packet_len']], df[features['fwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['packet_len_mean']], df[features['fwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['packet_len_std']], df[features['bwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['packet_len_variance']], df[features['bwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['rst_flag_count']], df[features['fwd_psh_flags']])
plt.show()

# %%
plt.scatter(df[features['avg_packet_size']], df[features['fwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['avg_fwd_seg_size']], df[features['fwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['avg_bwd_seg_size']], df[features['bwd_packet_len_max']])
plt.show()

# %%
plt.scatter(df[features['bwd_packet_len_mean']], df[features['bwd_packet_len_max']])
plt.show()
